# %%
import multiprocessing
import os
import pickle
import warnings
from collections import Counter

import numpy as np
import optuna
import pandas as pd
import requests
from implicit.als import AlternatingLeastSquares
from lightfm import LightFM
from rectools import Columns
from rectools.dataset import Dataset
from rectools.metrics import calc_metrics, MAP, MeanInvUserFreq, Serendipity
from rectools.models import ImplicitALSWrapperModel, LightFMWrapperModel
from rectools.models.popular import PopularModel
from tqdm.auto import tqdm

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# # Get KION dataset

# %%
# download dataset by chunks
url = (
    'https://storage.yandexcloud.net/'
    'itmo-recsys-public-data/kion_train.zip'
)

req = requests.get(url, stream=True)

with open('kion_train.zip', 'wb') as fd:
    total_size_in_bytes = int(req.headers.get('Content-Length', 0))
    progress_bar = tqdm(
        desc='kion dataset download',
        total=total_size_in_bytes,
        unit='iB',
        unit_scale=True,
    )
    for chunk in req.iter_content(chunk_size=2 ** 20):
        progress_bar.update(len(chunk))
        fd.write(chunk)
# Out:
# kion dataset download:   0%|          | 0.00/78.8M [00:00<?, ?iB/s]

# %%
# !unzip -o kion_train.zip
# Out:
# Archive:  kion_train.zip
#   inflating: kion_train/interactions.csv
#   inflating: __MACOSX/kion_train/._interactions.csv
#   inflating: kion_train/users.csv
#   inflating: __MACOSX/kion_train/._users.csv
#   inflating: kion_train/items.csv
#   inflating: __MACOSX/kion_train/._items.csv

# %% [markdown]
# # Data utils

# %%
def read_data():
    interactions = pd.read_csv('kion_train/interactions.csv')
    users = pd.read_csv('kion_train/users.csv')
    items = pd.read_csv('kion_train/items.csv')

    interactions.rename(
        columns={'last_watch_dt': Columns.Datetime},
        inplace=True,
    )

    interactions[Columns.Datetime] = pd.to_datetime(interactions[Columns.Datetime])
    interactions[Columns.Weight] = np.where(interactions['watched_pct'] > 10, 3, 1)
    
    users.fillna('Unknown', inplace=True)

    items['genre_list'] = items['genres'].apply(lambda genres: genres.split(', '))
    genre_counter = Counter(items['genre_list'].explode())
    genre_names = list(map(lambda x: x[0], genre_counter.most_common(10)))
    for genre_name in genre_names:
        is_current_genre = []
        for genre_list in items['genres']:
            is_current_genre.append(int(genre_name in genre_list))
        items[genre_name] = is_current_genre

    return interactions, users, items

# %%
def train_test_split(df, filter_cold_users, time_delta):
    max_date = df[Columns.Datetime].max()
    train = df[df[Columns.Datetime] < max_date - time_delta].copy()
    test = df[df[Columns.Datetime] >= max_date - time_delta].copy()
    
    if filter_cold_users:
        cold_users = set(test[Columns.User]) - set(train[Columns.User])
        test.drop(test[test[Columns.User].isin(cold_users)].index, inplace=True)
        
    return train, test

# %%
def get_user_features(users, features):
    user_features_frames = []
    for feature in features:
        feature_frame = users.reindex(columns=[Columns.User, feature])
        feature_frame.columns = ['id', 'value']
        feature_frame['feature'] = feature
        user_features_frames.append(feature_frame)
    return pd.concat(user_features_frames)

def get_item_features(items, features):
    item_features_frames = []
    for feature in features:
        feature_frame = items.reindex(columns=[Columns.Item, feature])
        feature_frame.columns = ['id', 'value']
        feature_frame['feature'] = feature
        item_features_frames.append(feature_frame)
    return pd.concat(item_features_frames)

# %% [markdown]
# # Objective class

# %%
class Objective(object):
    def __init__(
        self,
        dataset,
        train,
        test,
        metrics,
        objective_metric,
        seed=42,
    ):
        self.dataset = dataset
        self.train = train
        self.test = test
        self.metrics = metrics
        self.objective_metric = objective_metric
        self.seed = seed
        self.trials = []
        self.catalog = self.train[Columns.Item].unique()

    def __call__(self, trial):
        model = self.get_model(trial)
        
        for past_trial in trial.study.trials:
            if past_trial.state != optuna.trial.TrialState.COMPLETE:
                continue

            if past_trial.params == trial.params:
                return past_trial.value
        
        print('Params: {0}'.format(trial.params))
        
        model.fit(self.dataset)

        test_users = self.test[Columns.User].unique()

        recos = model.recommend(
            users=test_users,
            dataset=self.dataset,
            k=10,
            filter_viewed=True,
        )

        metric_values = calc_metrics(
            self.metrics, recos, self.test, self.train, self.catalog,
        )

        report = trial.params.copy()
        report.update(metric_values)

        self.trials.append(report)

        return metric_values[self.objective_metric]

    def get_model(self, trial):
        model_type = trial.suggest_categorical('model', ['ALS', 'FM', 'Popular'])
        if model_type == 'ALS':
            return self._get_als_model(trial)
        elif model_type == 'FM':
            return self._get_fm_model(trial)
        else:
            return PopularModel()

    def _get_als_model(self, trial):
        n_components = trial.suggest_int('n_components', 1, 64)
        fit_features_together = trial.suggest_categorical(
            'fit_features_together', [True, False],
        )
        
        regularization = trial.suggest_float('regularization', 0, 0.1)

        return ImplicitALSWrapperModel(
            model=AlternatingLeastSquares(
                factors=n_components,
                regularization=regularization,
                random_state=self.seed,
                num_threads=multiprocessing.cpu_count(),
            ),
            fit_features_together=fit_features_together,
        )

    def _get_fm_model(self, trial):
        n_components = trial.suggest_int('n_components', 1, 64)
        loss = trial.suggest_categorical(
            'loss', ['bpr', 'warp'],
        )
        
        user_alpha = trial.suggest_float('user_alpha', 0, 0.1)
        item_alpha = trial.suggest_float('item_alpha', 0, 0.1)

        return LightFMWrapperModel(
            LightFM(
                no_components=n_components,
                loss=loss,
                random_state=self.seed,
                user_alpha=user_alpha,
                item_alpha=item_alpha,
            ),
            epochs=1,
            num_threads=multiprocessing.cpu_count(),
        )

# %% [markdown]
# # Model saving

# %%
def save_model(model, dirname, model_type, dataset, interactions):
    if model_type == 'ALS':
        user_embeddings, item_embeddings = best_model.get_vectors()
    else:
        user_embeddings, item_embeddings = best_model.get_vectors(dataset)
        
    if not os.path.isdir(dirname):
        os.mkdir(dirname)
        
    attr_values = [user_embeddings, item_embeddings, interactions]
    attr_names = ['user_embeddings', 'item_embeddings', 'interactions']
    
    for attr_value, attr_name in zip(attr_values, attr_names):
        attr_filename = os.path.join(
            dirname, '{0}.pickle'.format(attr_name),
        )
        with open(attr_filename, 'wb') as attr_file:
            pickle.dump(attr_value, attr_file)

# %%
interactions, users, items = read_data()

# %%
# Создадим автаров
avatar_items = [
    # Отечественные комедийные сериалы
    ['Кухня', 'Сваты', 'Ивановы'],
    # Детский контент
    ['Ми-ми-мишки', 'Мама для мамонтёнка', 'Дядюшка Ау'],
    # Боевики, выпущенные до 2000 года
    ['Терминатор', 'Рэмбо: Первая кровь', 'Робокоп']
]
avatar_ids = []


avatar_interactions = []
for idx in range(len(avatar_items)):
    avatar_id = interactions[Columns.User].max() + idx + 1
    avatar_ids.append(avatar_id)
    for title in avatar_items[idx]:
        datetime = interactions[Columns.Datetime].min()
        item_id = items[items['title'] == title][Columns.Item].iloc[0]
        avatar_interactions.append([avatar_id, item_id, datetime, 0, 0, 3])

# Добавим аватров в датафрейм
interactions = pd.concat(
    [
        interactions,
        pd.DataFrame(avatar_interactions, columns=interactions.columns),
    ],
    ignore_index=True,
)

# %%
# Разобьем выборку
train, test = train_test_split(interactions, True, pd.Timedelta(days=7))

# Получим признаки для итемов и пользователей
users = users.loc[users[Columns.User].isin(train[Columns.User])].copy()
items = items.loc[items[Columns.Item].isin(train[Columns.Item])].copy()

user_features = get_user_features(users, ['sex', 'age', 'income'])
item_features = get_item_features(items, ['content_type'] + items.columns[-10:].tolist())

# Создадим датасет только из тренировочной части данных
dataset = Dataset.construct(
    interactions_df=train,
    user_features_df=user_features,
    cat_user_features=['sex', 'age', 'income'],
    item_features_df=item_features,
    cat_item_features=['content_type'] + items.columns[-10:].tolist(),
)

# %%
# Подбор параметров
metrics = {
    'MAP@10': MAP(k=10),
    'MeanInvUserFreq': MeanInvUserFreq(k=10),
    'Serendipity': Serendipity(k=10),
}

objective = Objective(
    dataset, train, test, metrics, 'MAP@10',
)
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=20)
# Out:
# [I 2022-12-13 21:59:48,714] A new study created in memory with name: no-name-7d8a9d76-ca67-406e-abdd-83f807708f8c
# Params: {'model': 'Popular'}
# [I 2022-12-13 21:59:55,173] Trial 0 finished with value: 0.07895709839298103 and parameters: {'model': 'Popular'}. Best is trial 0 with value: 0.07895709839298103.
# [I 2022-12-13 21:59:55,174] Trial 1 finished with value: 0.07895709839298103 and parameters: {'model': 'Popular'}. Best is trial 0 with value: 0.07895709839298103.
# [I 2022-12-13 21:59:55,175] Trial 2 finished with value: 0.07895709839298103 and parameters: {'model': 'Popular'}. Best is trial 0 with value: 0.07895709839298103.
# Params: {'model': 'FM', 'n_components': 63, 'loss': 'warp', 'user_alpha': 0.004719979864040203, 'item_alpha': 0.046488221793319295}
# [I 2022-12-13 22:03:32,795] Trial 3 finished with value: 0.00030275175685626004 and parameters: {'model': 'FM', 'n_components': 63, 'loss': 'warp', 'user_alpha': 0.004719979864040203, 'item_alpha': 0.046488221793319295}. Best is trial 0 with value: 0.07895709839298103.
# [I 2022-12-13 22:03:32,796] Trial 4 finished with value: 0.07895709839298103 and parameters: {'model': 'Popular'}. Best is trial 0 with value: 0.07895709839298103.
# WARNING:root:Intel MKL BLAS detected. Its highly recommend to set the environment variable 'export MKL_NUM_THREADS=1' to disable its internal multithreading
# Params: {'model': 'ALS', 'n_components': 46, 'fit_features_together': False, 'regularization': 0.07304523882398964}
# [I 2022-12-13 22:05:25,259] Trial 5 finished with value: 0.06544143743608777 and parameters: {'model': 'ALS', 'n_components': 46, 'fit_features_together': False, 'regularization': 0.07304523882398964}. Best is trial 0 with value: 0.07895709839298103.
# Params: {'model': 'FM', 'n_components': 29, 'loss': 'bpr', 'user_alpha': 0.008891914860545825, 'item_alpha': 0.03835102412240964}
# [I 2022-12-13 22:07:09,693] Trial 6 finished with value: 0.0 and parameters: {'model': 'FM', 'n_components': 29, 'loss': 'bpr', 'user_alpha': 0.008891914860545825, 'item_alpha': 0.03835102412240964}. Best is trial 0 with value: 0.07895709839298103.
# Params: {'model': 'FM', 'n_components': 20, 'loss': 'warp', 'user_alpha': 0.06443418986097918, 'item_alpha': 0.011348532028018499}
# [I 2022-12-13 22:08:36,657] Trial 7 finished with value: 0.07670489706245115 and parameters: {'model': 'FM', 'n_components': 20, 'loss': 'warp', 'user_alpha': 0.06443418986097918, 'item_alpha': 0.011348532028018499}. Best is trial 0 with value: 0.07895709839298103.
# [I 2022-12-13 22:08:36,659] Trial 8 finished with value: 0.07895709839298103 and parameters: {'model': 'Popular'}. Best is trial 0 with value: 0.07895709839298103.
# Params: {'model': 'FM', 'n_components': 11, 'loss': 'warp', 'user_alpha': 0.010056565400803453, 'item_alpha': 0.055898006020603325}
# [I 2022-12-13 22:09:45,309] Trial 9 finished with value: 0.0333803283274062 and parameters: {'model': 'FM', 'n_components': 11, 'loss': 'warp', 'user_alpha': 0.010056565400803453, 'item_alpha': 0.055898006020603325}. Best is trial 0 with value: 0.07895709839298103.
# Params: {'model': 'ALS', 'n_components': 5, 'fit_features_together': True, 'regularization': 0.004382992604813327}
# [I 2022-12-13 22:10:45,985] Trial 10 finished with value: 0.08045767529939321 and parameters: {'model': 'ALS', 'n_components': 5, 'fit_features_together': True, 'regularization': 0.004382992604813327}. Best is trial 10 with value: 0.08045767529939321.
# Params: {'model': 'ALS', 'n_components': 4, 'fit_features_together': True, 'regularization': 0.003027686351279978}
# [I 2022-12-13 22:11:46,939] Trial 11 finished with value: 0.08057808825090312 and parameters: {'model': 'ALS', 'n_components': 4, 'fit_features_together': True, 'regularization': 0.003027686351279978}. Best is trial 11 with value: 0.08057808825090312.
# Params: {'model': 'ALS', 'n_components': 1, 'fit_features_together': True, 'regularization': 0.0002480831373961271}
# [I 2022-12-13 22:12:45,253] Trial 12 finished with value: 0.080279767511658 and parameters: {'model': 'ALS', 'n_components': 1, 'fit_features_together': True, 'regularization': 0.0002480831373961271}. Best is trial 11 with value: 0.08057808825090312.
# Params: {'model': 'ALS', 'n_components': 1, 'fit_features_together': True, 'regularization': 0.0023987648656378056}
# [I 2022-12-13 22:13:41,661] Trial 13 finished with value: 0.08105730133559175 and parameters: {'model': 'ALS', 'n_components': 1, 'fit_features_together': True, 'regularization': 0.0023987648656378056}. Best is trial 13 with value: 0.08105730133559175.
# Params: {'model': 'ALS', 'n_components': 17, 'fit_features_together': True, 'regularization': 0.029058039098230903}
# [I 2022-12-13 22:14:54,199] Trial 14 finished with value: 0.07970530741585087 and parameters: {'model': 'ALS', 'n_components': 17, 'fit_features_together': True, 'regularization': 0.029058039098230903}. Best is trial 13 with value: 0.08105730133559175.
# Params: {'model': 'ALS', 'n_components': 1, 'fit_features_together': True, 'regularization': 0.03486005015079774}
# [I 2022-12-13 22:15:52,229] Trial 15 finished with value: 0.08121831189440205 and parameters: {'model': 'ALS', 'n_components': 1, 'fit_features_together': True, 'regularization': 0.03486005015079774}. Best is trial 15 with value: 0.08121831189440205.
# Params: {'model': 'ALS', 'n_components': 31, 'fit_features_together': True, 'regularization': 0.04845603352116515}
# [I 2022-12-13 22:17:24,841] Trial 16 finished with value: 0.07900839611532838 and parameters: {'model': 'ALS', 'n_components': 31, 'fit_features_together': True, 'regularization': 0.04845603352116515}. Best is trial 15 with value: 0.08121831189440205.
# Params: {'model': 'ALS', 'n_components': 44, 'fit_features_together': False, 'regularization': 0.03233576255784106}
# [I 2022-12-13 22:19:13,857] Trial 17 finished with value: 0.0652430513611751 and parameters: {'model': 'ALS', 'n_components': 44, 'fit_features_together': False, 'regularization': 0.03233576255784106}. Best is trial 15 with value: 0.08121831189440205.
# Params: {'model': 'ALS', 'n_components': 16, 'fit_features_together': True, 'regularization': 0.09828574070541736}
# [I 2022-12-13 22:20:25,869] Trial 18 finished with value: 0.08009869987538755 and parameters: {'model': 'ALS', 'n_components': 16, 'fit_features_together': True, 'regularization': 0.09828574070541736}. Best is trial 15 with value: 0.08121831189440205.
# Params: {'model': 'ALS', 'n_components': 23, 'fit_features_together': True, 'regularization': 0.02493167335696917}
# [I 2022-12-13 22:21:47,309] Trial 19 finished with value: 0.07909353103382936 and parameters: {'model': 'ALS', 'n_components': 23, 'fit_features_together': True, 'regularization': 0.02493167335696917}. Best is trial 15 with value: 0.08121831189440205.

# %%
report = pd.DataFrame(objective.trials).fillna('-')
report.sort_values(objective.objective_metric, inplace=True, ascending=False)

metric_columns = ['Serendipity', 'MeanInvUserFreq', 'MAP@10']

columns = []
for column in report.columns:
    if column not in metric_columns:
        columns.append(column)
columns.extend(metric_columns)

report = report[columns]

def highlight_metric(row):
    return 'background-color: lightcyan'

report.head(20).style.applymap(
    highlight_metric, 
    subset=pd.IndexSlice[:, [objective.objective_metric]],
)
# Out:
# <style type="text/css">
# #T_a4273_row0_col9, #T_a4273_row1_col9, #T_a4273_row2_col9, #T_a4273_row3_col9, #T_a4273_row4_col9, #T_a4273_row5_col9, #T_a4273_row6_col9, #T_a4273_row7_col9, #T_a4273_row8_col9, #T_a4273_row9_col9, #T_a4273_row10_col9, #T_a4273_row11_col9, #T_a4273_row12_col9, #T_a4273_row13_col9, #T_a4273_row14_col9, #T_a4273_row15_col9 {
#   background-color: lightcyan;
# }
# </style>
# <table id="T_a4273">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4273_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_a4273_level0_col1" class="col_heading level0 col1" >n_components</th>
#       <th id="T_a4273_level0_col2" class="col_heading level0 col2" >loss</th>
#       <th id="T_a4273_level0_col3" class="col_heading level0 col3" >user_alpha</th>
#       <th id="T_a4273_level0_col4" class="col_heading level0 col4" >item_alpha</th>
#       <th id="T_a4273_level0_col5" class="col_heading level0 col5" >fit_features_together</th>
#       <th id="T_a4273_level0_col6" class="col_heading level0 col6" >regularization</th>
#       <th id="T_a4273_level0_col7" class="col_heading level0 col7" >Serendipity</th>
#       <th id="T_a4273_level0_col8" class="col_heading level0 col8" >MeanInvUserFreq</th>
#       <th id="T_a4273_level0_col9" class="col_heading level0 col9" >MAP@10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4273_level0_row0" class="row_heading level0 row0" >11</th>
#       <td id="T_a4273_row0_col0" class="data row0 col0" >ALS</td>
#       <td id="T_a4273_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_a4273_row0_col2" class="data row0 col2" >-</td>
#       <td id="T_a4273_row0_col3" class="data row0 col3" >-</td>
#       <td id="T_a4273_row0_col4" class="data row0 col4" >-</td>
#       <td id="T_a4273_row0_col5" class="data row0 col5" >True</td>
#       <td id="T_a4273_row0_col6" class="data row0 col6" >0.034860</td>
#       <td id="T_a4273_row0_col7" class="data row0 col7" >0.000008</td>
#       <td id="T_a4273_row0_col8" class="data row0 col8" >4.183457</td>
#       <td id="T_a4273_row0_col9" class="data row0 col9" >0.081218</td>
#     </tr>
#     <tr>
#       <th id="T_a4273_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_a4273_row1_col0" class="data row1 col0" >ALS</td>
#       <td id="T_a4273_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a4273_row1_col2" class="data row1 col2" >-</td>
#       <td id="T_a4273_row1_col3" class="data row1 col3" >-</td>
#       <td id="T_a4273_row1_col4" class="data row1 col4" >-</td>
#       <td id="T_a4273_row1_col5" class="data row1 col5" >True</td>
#       <td id="T_a4273_row1_col6" class="data row1 col6" >0.002399</td>
#       <td id="T_a4273_row1_col7" class="data row1 col7" >0.000009</td>
#       <td id="T_a4273_row1_col8" class="data row1 col8" >4.178566</td>
#       <td id="T_a4273_row1_col9" class="data row1 col9" >0.081057</td>
#     </tr>
#     <tr>
#       <th id="T_a4273_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_a4273_row2_col0" class="data row2 col0" >ALS</td>
#       <td id="T_a4273_row2_col1" class="data row2 col1" >4.000000</td>
#       <td id="T_a4273_row2_col2" class="data row2 col2" >-</td>
#       <td id="T_a4273_row2_col3" class="data row2 col3" >-</td>
#       <td id="T_a4273_row2_col4" class="data row2 col4" >-</td>
#       <td id="T_a4273_row2_col5" class="data row2 col5" >True</td>
#       <td id="T_a4273_row2_col6" class="data row2 col6" >0.003028</td>
#       <td id="T_a4273_row2_col7" class="data row2 col7" >0.000005</td>
#       <td id="T_a4273_row2_col8" class="data row2 col8" >3.947866</td>
#       <td id="T_a4273_row2_col9" class="data row2 col9" >0.080578</td>
#     </tr>
#     <tr>
#       <th id="T_a4273_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_a4273_row3_col0" class="data row3 col0" >ALS</td>
#       <td id="T_a4273_row3_col1" class="data row3 col1" >5.000000</td>
#       <td id="T_a4273_row3_col2" class="data row3 col2" >-</td>
#       <td id="T_a4273_row3_col3" class="data row3 col3" >-</td>
#       <td id="T_a4273_row3_col4" class="data row3 col4" >-</td>
#       <td id="T_a4273_row3_col5" class="data row3 col5" >True</td>
#       <td id="T_a4273_row3_col6" class="data row3 col6" >0.004383</td>
#       <td id="T_a4273_row3_col7" class="data row3 col7" >0.000005</td>
#       <td id="T_a4273_row3_col8" class="data row3 col8" >3.934947</td>
#       <td id="T_a4273_row3_col9" class="data row3 col9" >0.080458</td>
#     </tr>
#     <tr>
#       <th id="T_a4273_level0_row4" class="row_heading level0 row4" >8</th>
#       <td id="T_a4273_row4_col0" class="data row4 col0" >ALS</td>
#       <td id="T_a4273_row4_col1" class="data row4 col1" >1.000000</td>
#       <td id="T_a4273_row4_col2" class="data row4 col2" >-</td>
#       <td id="T_a4273_row4_col3" class="data row4 col3" >-</td>
#       <td id="T_a4273_row4_col4" class="data row4 col4" >-</td>
#       <td id="T_a4273_row4_col5" class="data row4 col5" >True</td>
#       <td id="T_a4273_row4_col6" class="data row4 col6" >0.000248</td>
#       <td id="T_a4273_row4_col7" class="data row4 col7" >0.000007</td>
#       <td id="T_a4273_row4_col8" class="data row4 col8" >4.153913</td>
#       <td id="T_a4273_row4_col9" class="data row4 col9" >0.080280</td>
#     </tr>
#     <tr>
#       <th id="T_a4273_level0_row5" class="row_heading level0 row5" >14</th>
#       <td id="T_a4273_row5_col0" class="data row5 col0" >ALS</td>
#       <td id="T_a4273_row5_col1" class="data row5 col1" >16.000000</td>
#       <td id="T_a4273_row5_col2" class="data row5 col2" >-</td>
#       <td id="T_a4273_row5_col3" class="data row5 col3" >-</td>
#       <td id="T_a4273_row5_col4" class="data row5 col4" >-</td>
#       <td id="T_a4273_row5_col5" class="data row5 col5" >True</td>
#       <td id="T_a4273_row5_col6" class="data row5 col6" >0.098286</td>
#       <td id="T_a4273_row5_col7" class="data row5 col7" >0.000005</td>
#       <td id="T_a4273_row5_col8" class="data row5 col8" >3.920305</td>
#       <td id="T_a4273_row5_col9" class="data row5 col9" >0.080099</td>
#     </tr>
#     <tr>
#       <th id="T_a4273_level0_row6" class="row_heading level0 row6" >10</th>
#       <td id="T_a4273_row6_col0" class="data row6 col0" >ALS</td>
#       <td id="T_a4273_row6_col1" class="data row6 col1" >17.000000</td>
#       <td id="T_a4273_row6_col2" class="data row6 col2" >-</td>
#       <td id="T_a4273_row6_col3" class="data row6 col3" >-</td>
#       <td id="T_a4273_row6_col4" class="data row6 col4" >-</td>
#       <td id="T_a4273_row6_col5" class="data row6 col5" >True</td>
#       <td id="T_a4273_row6_col6" class="data row6 col6" >0.029058</td>
#       <td id="T_a4273_row6_col7" class="data row6 col7" >0.000005</td>
#       <td id="T_a4273_row6_col8" class="data row6 col8" >3.948040</td>
#       <td id="T_a4273_row6_col9" class="data row6 col9" >0.079705</td>
#     </tr>
#     <tr>
#       <th id="T_a4273_level0_row7" class="row_heading level0 row7" >15</th>
#       <td id="T_a4273_row7_col0" class="data row7 col0" >ALS</td>
#       <td id="T_a4273_row7_col1" class="data row7 col1" >23.000000</td>
#       <td id="T_a4273_row7_col2" class="data row7 col2" >-</td>
#       <td id="T_a4273_row7_col3" class="data row7 col3" >-</td>
#       <td id="T_a4273_row7_col4" class="data row7 col4" >-</td>
#       <td id="T_a4273_row7_col5" class="data row7 col5" >True</td>
#       <td id="T_a4273_row7_col6" class="data row7 col6" >0.024932</td>
#       <td id="T_a4273_row7_col7" class="data row7 col7" >0.000005</td>
#       <td id="T_a4273_row7_col8" class="data row7 col8" >3.994778</td>
#       <td id="T_a4273_row7_col9" class="data row7 col9" >0.079094</td>
#     </tr>
#     <tr>
#       <th id="T_a4273_level0_row8" class="row_heading level0 row8" >12</th>
#       <td id="T_a4273_row8_col0" class="data row8 col0" >ALS</td>
#       <td id="T_a4273_row8_col1" class="data row8 col1" >31.000000</td>
#       <td id="T_a4273_row8_col2" class="data row8 col2" >-</td>
#       <td id="T_a4273_row8_col3" class="data row8 col3" >-</td>
#       <td id="T_a4273_row8_col4" class="data row8 col4" >-</td>
#       <td id="T_a4273_row8_col

# %%
# Сохраним лучшую модель обученную только на train
best_model = objective.get_model(study.best_trial)
best_model.fit(dataset)

save_model(
    best_model,
    'partial_best_model',
    study.best_trial.params['model'],
    dataset,
    train,
)

# %%
# Посмотрим на рекомендации для аватаров от модели с лучшим показателем MAP@10
colors = ['lavender', 'wheat', 'mistyrose']
color_map = {avatar_id: color for avatar_id, color in zip(avatar_ids, colors)}

def highlight_avatars(row):
    color = color_map[row[0]]
    return ['background-color: {0}'.format(color)] * len(row.values)

avatar_recs = best_model.recommend(
    users=avatar_ids,
    dataset=dataset,
    k=10,
    filter_viewed=True,
).merge(
    items[[Columns.Item, 'title']],
    on=Columns.Item,
).sort_values(
    [Columns.User, Columns.Rank],
)

avatar_recs.style.apply(highlight_avatars, axis=1)
# Out:
# <style type="text/css">
# #T_337ef_row0_col0, #T_337ef_row0_col1, #T_337ef_row0_col2, #T_337ef_row0_col3, #T_337ef_row0_col4, #T_337ef_row1_col0, #T_337ef_row1_col1, #T_337ef_row1_col2, #T_337ef_row1_col3, #T_337ef_row1_col4, #T_337ef_row2_col0, #T_337ef_row2_col1, #T_337ef_row2_col2, #T_337ef_row2_col3, #T_337ef_row2_col4, #T_337ef_row3_col0, #T_337ef_row3_col1, #T_337ef_row3_col2, #T_337ef_row3_col3, #T_337ef_row3_col4, #T_337ef_row4_col0, #T_337ef_row4_col1, #T_337ef_row4_col2, #T_337ef_row4_col3, #T_337ef_row4_col4, #T_337ef_row5_col0, #T_337ef_row5_col1, #T_337ef_row5_col2, #T_337ef_row5_col3, #T_337ef_row5_col4, #T_337ef_row6_col0, #T_337ef_row6_col1, #T_337ef_row6_col2, #T_337ef_row6_col3, #T_337ef_row6_col4, #T_337ef_row7_col0, #T_337ef_row7_col1, #T_337ef_row7_col2, #T_337ef_row7_col3, #T_337ef_row7_col4, #T_337ef_row8_col0, #T_337ef_row8_col1, #T_337ef_row8_col2, #T_337ef_row8_col3, #T_337ef_row8_col4, #T_337ef_row9_col0, #T_337ef_row9_col1, #T_337ef_row9_col2, #T_337ef_row9_col3, #T_337ef_row9_col4 {
#   background-color: lavender;
# }
# #T_337ef_row10_col0, #T_337ef_row10_col1, #T_337ef_row10_col2, #T_337ef_row10_col3, #T_337ef_row10_col4, #T_337ef_row11_col0, #T_337ef_row11_col1, #T_337ef_row11_col2, #T_337ef_row11_col3, #T_337ef_row11_col4, #T_337ef_row12_col0, #T_337ef_row12_col1, #T_337ef_row12_col2, #T_337ef_row12_col3, #T_337ef_row12_col4, #T_337ef_row13_col0, #T_337ef_row13_col1, #T_337ef_row13_col2, #T_337ef_row13_col3, #T_337ef_row13_col4, #T_337ef_row14_col0, #T_337ef_row14_col1, #T_337ef_row14_col2, #T_337ef_row14_col3, #T_337ef_row14_col4, #T_337ef_row15_col0, #T_337ef_row15_col1, #T_337ef_row15_col2, #T_337ef_row15_col3, #T_337ef_row15_col4, #T_337ef_row16_col0, #T_337ef_row16_col1, #T_337ef_row16_col2, #T_337ef_row16_col3, #T_337ef_row16_col4, #T_337ef_row17_col0, #T_337ef_row17_col1, #T_337ef_row17_col2, #T_337ef_row17_col3, #T_337ef_row17_col4, #T_337ef_row18_col0, #T_337ef_row18_col1, #T_337ef_row18_col2, #T_337ef_row18_col3, #T_337ef_row18_col4, #T_337ef_row19_col0, #T_337ef_row19_col1, #T_337ef_row19_col2, #T_337ef_row19_col3, #T_337ef_row19_col4 {
#   background-color: wheat;
# }
# #T_337ef_row20_col0, #T_337ef_row20_col1, #T_337ef_row20_col2, #T_337ef_row20_col3, #T_337ef_row20_col4, #T_337ef_row21_col0, #T_337ef_row21_col1, #T_337ef_row21_col2, #T_337ef_row21_col3, #T_337ef_row21_col4, #T_337ef_row22_col0, #T_337ef_row22_col1, #T_337ef_row22_col2, #T_337ef_row22_col3, #T_337ef_row22_col4, #T_337ef_row23_col0, #T_337ef_row23_col1, #T_337ef_row23_col2, #T_337ef_row23_col3, #T_337ef_row23_col4, #T_337ef_row24_col0, #T_337ef_row24_col1, #T_337ef_row24_col2, #T_337ef_row24_col3, #T_337ef_row24_col4, #T_337ef_row25_col0, #T_337ef_row25_col1, #T_337ef_row25_col2, #T_337ef_row25_col3, #T_337ef_row25_col4, #T_337ef_row26_col0, #T_337ef_row26_col1, #T_337ef_row26_col2, #T_337ef_row26_col3, #T_337ef_row26_col4, #T_337ef_row27_col0, #T_337ef_row27_col1, #T_337ef_row27_col2, #T_337ef_row27_col3, #T_337ef_row27_col4, #T_337ef_row28_col0, #T_337ef_row28_col1, #T_337ef_row28_col2, #T_337ef_row28_col3, #T_337ef_row28_col4, #T_337ef_row29_col0, #T_337ef_row29_col1, #T_337ef_row29_col2, #T_337ef_row29_col3, #T_337ef_row29_col4 {
#   background-color: mistyrose;
# }
# </style>
# <table id="T_337ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_337ef_level0_col0" class="col_heading level0 col0" >user_id</th>
#       <th id="T_337ef_level0_col1" class="col_heading level0 col1" >item_id</th>
#       <th id="T_337ef_level0_col2" class="col_heading level0 col2" >score</th>
#       <th id="T_337ef_level0_col3" class="col_heading level0 col3" >rank</th>
#       <th id="T_337ef_level0_col4" class="col_heading level0 col4" >title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_337ef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_337ef_row0_col0" class="data row0 col0" >1097558</td>
#       <td id="T_337ef_row0_col1" class="data row0 col1" >15297</td>
#       <td id="T_337ef_row0_col2" class="data row0 col2" >0.378224</td>
#       <td id="T_337ef_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_337ef_row0_col4" class="data row0 col4" >Клиника счастья</td>
#     </tr>
#     <tr>
#       <th id="T_337ef_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_337ef_row1_col0" class="data row1 col0" >1097558</td>
#       <td id="T_337ef_row1_col1" class="data row1 col1" >10440</td>
#       <td id="T_337ef_row1_col2" class="data row1 col2" >0.335288</td>
#       <td id="T_337ef_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_337ef_row1_col4" class="data row1 col4" >Хрустальный</td>
#     </tr>
#     <tr>
#       <th id="T_337ef_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_337ef_row2_col0" class="data row2 col0" >1097558</td>
#       <td id="T_337ef_row2_col1" class="data row2 col1" >4151</td>
#       <td id="T_337ef_row2_col2" class="data row2 col2" >0.257319</td>
#       <td id="T_337ef_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_337ef_row2_col4" class="data row2 col4" >Секреты семейной жизни</td>
#     </tr>
#     <tr>
#       <th id="T_337ef_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_337ef_row3_col0" class="data row3 col0" >1097558</td>
#       <td id="T_337ef_row3_col1" class="data row3 col1" >3734</td>
#       <td id="T_337ef_row3_col2" class="data row3 col2" >0.255944</td>
#       <td id="T_337ef_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_337ef_row3_col4" class="data row3 col4" >Прабабушка легкого поведения</td>
#     </tr>
#     <tr>
#       <th id="T_337ef_level0_row4" class="row_heading level0 row4" >10</th>
#       <td id="T_337ef_row4_col0" class="data row4 col0" >1097558</td>
#       <td id="T_337ef_row4_col1" class="data row4 col1" >9728</td>
#       <td id="T_337ef_row4_col2" class="data row4 col2" >0.223026</td>
#       <td id="T_337ef_row4_col3" class="data row4 col3" >5</td>
#       <td id="T_337ef_row4_col4" class="data row4 col4" >Гнев человеческий</td>
#     </tr>
#     <tr>
#       <th id="T_337ef_level0_row5" class="row_heading level0 row5" >13</th>
#       <td id="T_337ef_row5_col0" class="data row5 col0" >1097558</td>
#       <td id="T_337ef_row5_col1" class="data row5 col1" >2657</td>
#       <td id="T_337ef_row5_col2" class="data row5 col2" >0.150892</td>
#       <td id="T_337ef_row5_col3" class="data row5 col3" >6</td>
#       <td id="T_337ef_row5_col4" class="data row5 col4" >Подслушано</td>
#     </tr>
#     <tr>
#       <th id="T_337ef_level0_row6" class="row_heading level0 row6" >15</th>
#       <td id="T_337ef_row6_col0" class="data row6 col0" >1097558</td>
#       <td id="T_337ef_row6_col1" class="data row6 col1" >13865</td>
#       <td id="T_337ef_row6_col2" class="data row6 col2" >0.138140</td>
#       <td id="T_337ef_row6_col3" class="data row6 col3" >7</td>
#       <td id="T_337ef_row6_col4" class="data row6 col4" >Девятаев</td>
#     </tr>
#     <tr>
#       <th id="T_337ef_level0_row7" class="row_heading level0 row7" >17</th>
#       <td id="T_337ef_row7_col0" class="data row7 col0" >1097558</td>
#       <td id="T_337ef_row7_col1" class="data row7 col1" >7571</td>
#       <td id="T_337ef_row7_col2" class="data row7 col2" >0.087007</td>
#       <td id="T_337ef_row7_col3" class="data row7 col3" >8</td>
#       <td id="T_337ef_row7_col4" class="data row7 col4" >100% волк</td>
#     </tr>
#     <tr>
#       <th id="T_337ef_level0_row8" class="row_heading level0 row8" >18</th>
#       <td id="T_337ef_row8_col0" class="data row8 col0" >1097558</td>
#       <td id="T_337ef_row8_col1" class="data row8 col1" >14431</td>
#       <td id="T_337ef_row8_col2" class="data row8 col2" >0.086529</td>
#       <td id="T_337ef_row8_col3" class="data row8 col3" >9</td>
#       <td id="T_337ef_row8_col4" class="data row8 col4" >Приворот. Чёрное венчание</td>
#     </tr>
#     <tr>
#       <th id="T_337ef_level0_row9" class="row_heading level0 row9" >19</th>
#       <td id="T_337ef_row9_col0" class="data row9 col0" >1097558</td>
#       <td id="T_337ef_row9_col1" class="data row9 col1" >4880</td>
#       <td id="T_337e

# %%
# Посмотрим на рекомендации для аватаров от модели с лучшим показателем MeanInvUserFreq
trial_idx = report.sort_values('MeanInvUserFreq', ascending=False).index[0]
model = objective.get_model(study.trials[trial_idx])
model.fit(dataset)

avatar_recs = model.recommend(
    users=avatar_ids,
    dataset=dataset,
    k=10,
    filter_viewed=True,
).merge(
    items[[Columns.Item, 'title']],
    on=Columns.Item,
).sort_values(
    [Columns.User, Columns.Rank],
)

avatar_recs.style.apply(highlight_avatars, axis=1)
# Out:
# <style type="text/css">
# #T_164bf_row0_col0, #T_164bf_row0_col1, #T_164bf_row0_col2, #T_164bf_row0_col3, #T_164bf_row0_col4, #T_164bf_row1_col0, #T_164bf_row1_col1, #T_164bf_row1_col2, #T_164bf_row1_col3, #T_164bf_row1_col4, #T_164bf_row2_col0, #T_164bf_row2_col1, #T_164bf_row2_col2, #T_164bf_row2_col3, #T_164bf_row2_col4, #T_164bf_row3_col0, #T_164bf_row3_col1, #T_164bf_row3_col2, #T_164bf_row3_col3, #T_164bf_row3_col4, #T_164bf_row4_col0, #T_164bf_row4_col1, #T_164bf_row4_col2, #T_164bf_row4_col3, #T_164bf_row4_col4, #T_164bf_row5_col0, #T_164bf_row5_col1, #T_164bf_row5_col2, #T_164bf_row5_col3, #T_164bf_row5_col4, #T_164bf_row6_col0, #T_164bf_row6_col1, #T_164bf_row6_col2, #T_164bf_row6_col3, #T_164bf_row6_col4, #T_164bf_row7_col0, #T_164bf_row7_col1, #T_164bf_row7_col2, #T_164bf_row7_col3, #T_164bf_row7_col4, #T_164bf_row8_col0, #T_164bf_row8_col1, #T_164bf_row8_col2, #T_164bf_row8_col3, #T_164bf_row8_col4, #T_164bf_row9_col0, #T_164bf_row9_col1, #T_164bf_row9_col2, #T_164bf_row9_col3, #T_164bf_row9_col4 {
#   background-color: lavender;
# }
# #T_164bf_row10_col0, #T_164bf_row10_col1, #T_164bf_row10_col2, #T_164bf_row10_col3, #T_164bf_row10_col4, #T_164bf_row11_col0, #T_164bf_row11_col1, #T_164bf_row11_col2, #T_164bf_row11_col3, #T_164bf_row11_col4, #T_164bf_row12_col0, #T_164bf_row12_col1, #T_164bf_row12_col2, #T_164bf_row12_col3, #T_164bf_row12_col4, #T_164bf_row13_col0, #T_164bf_row13_col1, #T_164bf_row13_col2, #T_164bf_row13_col3, #T_164bf_row13_col4, #T_164bf_row14_col0, #T_164bf_row14_col1, #T_164bf_row14_col2, #T_164bf_row14_col3, #T_164bf_row14_col4, #T_164bf_row15_col0, #T_164bf_row15_col1, #T_164bf_row15_col2, #T_164bf_row15_col3, #T_164bf_row15_col4, #T_164bf_row16_col0, #T_164bf_row16_col1, #T_164bf_row16_col2, #T_164bf_row16_col3, #T_164bf_row16_col4, #T_164bf_row17_col0, #T_164bf_row17_col1, #T_164bf_row17_col2, #T_164bf_row17_col3, #T_164bf_row17_col4, #T_164bf_row18_col0, #T_164bf_row18_col1, #T_164bf_row18_col2, #T_164bf_row18_col3, #T_164bf_row18_col4, #T_164bf_row19_col0, #T_164bf_row19_col1, #T_164bf_row19_col2, #T_164bf_row19_col3, #T_164bf_row19_col4 {
#   background-color: wheat;
# }
# #T_164bf_row20_col0, #T_164bf_row20_col1, #T_164bf_row20_col2, #T_164bf_row20_col3, #T_164bf_row20_col4, #T_164bf_row21_col0, #T_164bf_row21_col1, #T_164bf_row21_col2, #T_164bf_row21_col3, #T_164bf_row21_col4, #T_164bf_row22_col0, #T_164bf_row22_col1, #T_164bf_row22_col2, #T_164bf_row22_col3, #T_164bf_row22_col4, #T_164bf_row23_col0, #T_164bf_row23_col1, #T_164bf_row23_col2, #T_164bf_row23_col3, #T_164bf_row23_col4, #T_164bf_row24_col0, #T_164bf_row24_col1, #T_164bf_row24_col2, #T_164bf_row24_col3, #T_164bf_row24_col4, #T_164bf_row25_col0, #T_164bf_row25_col1, #T_164bf_row25_col2, #T_164bf_row25_col3, #T_164bf_row25_col4, #T_164bf_row26_col0, #T_164bf_row26_col1, #T_164bf_row26_col2, #T_164bf_row26_col3, #T_164bf_row26_col4, #T_164bf_row27_col0, #T_164bf_row27_col1, #T_164bf_row27_col2, #T_164bf_row27_col3, #T_164bf_row27_col4, #T_164bf_row28_col0, #T_164bf_row28_col1, #T_164bf_row28_col2, #T_164bf_row28_col3, #T_164bf_row28_col4, #T_164bf_row29_col0, #T_164bf_row29_col1, #T_164bf_row29_col2, #T_164bf_row29_col3, #T_164bf_row29_col4 {
#   background-color: mistyrose;
# }
# </style>
# <table id="T_164bf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_164bf_level0_col0" class="col_heading level0 col0" >user_id</th>
#       <th id="T_164bf_level0_col1" class="col_heading level0 col1" >item_id</th>
#       <th id="T_164bf_level0_col2" class="col_heading level0 col2" >score</th>
#       <th id="T_164bf_level0_col3" class="col_heading level0 col3" >rank</th>
#       <th id="T_164bf_level0_col4" class="col_heading level0 col4" >title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_164bf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_164bf_row0_col0" class="data row0 col0" >1097558</td>
#       <td id="T_164bf_row0_col1" class="data row0 col1" >15902</td>
#       <td id="T_164bf_row0_col2" class="data row0 col2" >432461.303414</td>
#       <td id="T_164bf_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_164bf_row0_col4" class="data row0 col4" >Морские паразиты (с тифлокомментарием)</td>
#     </tr>
#     <tr>
#       <th id="T_164bf_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_164bf_row1_col0" class="data row1 col0" >1097558</td>
#       <td id="T_164bf_row1_col1" class="data row1 col1" >13329</td>
#       <td id="T_164bf_row1_col2" class="data row1 col2" >224356.116613</td>
#       <td id="T_164bf_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_164bf_row1_col4" class="data row1 col4" >Тихая Одесса</td>
#     </tr>
#     <tr>
#       <th id="T_164bf_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_164bf_row2_col0" class="data row2 col0" >1097558</td>
#       <td id="T_164bf_row2_col1" class="data row2 col1" >1138</td>
#       <td id="T_164bf_row2_col2" class="data row2 col2" >224137.245815</td>
#       <td id="T_164bf_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_164bf_row2_col4" class="data row2 col4" >Два мгновения любви</td>
#     </tr>
#     <tr>
#       <th id="T_164bf_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_164bf_row3_col0" class="data row3 col0" >1097558</td>
#       <td id="T_164bf_row3_col1" class="data row3 col1" >10432</td>
#       <td id="T_164bf_row3_col2" class="data row3 col2" >201723.211539</td>
#       <td id="T_164bf_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_164bf_row3_col4" class="data row3 col4" >Притворись моим мужем</td>
#     </tr>
#     <tr>
#       <th id="T_164bf_level0_row4" class="row_heading level0 row4" >11</th>
#       <td id="T_164bf_row4_col0" class="data row4 col0" >1097558</td>
#       <td id="T_164bf_row4_col1" class="data row4 col1" >2669</td>
#       <td id="T_164bf_row4_col2" class="data row4 col2" >158271.433597</td>
#       <td id="T_164bf_row4_col3" class="data row4 col3" >5</td>
#       <td id="T_164bf_row4_col4" class="data row4 col4" >Войцек</td>
#     </tr>
#     <tr>
#       <th id="T_164bf_level0_row5" class="row_heading level0 row5" >14</th>
#       <td id="T_164bf_row5_col0" class="data row5 col0" >1097558</td>
#       <td id="T_164bf_row5_col1" class="data row5 col1" >1595</td>
#       <td id="T_164bf_row5_col2" class="data row5 col2" >30753.210829</td>
#       <td id="T_164bf_row5_col3" class="data row5 col3" >6</td>
#       <td id="T_164bf_row5_col4" class="data row5 col4" >Счастье в конверте</td>
#     </tr>
#     <tr>
#       <th id="T_164bf_level0_row6" class="row_heading level0 row6" >16</th>
#       <td id="T_164bf_row6_col0" class="data row6 col0" >1097558</td>
#       <td id="T_164bf_row6_col1" class="data row6 col1" >1999</td>
#       <td id="T_164bf_row6_col2" class="data row6 col2" >7312.630618</td>
#       <td id="T_164bf_row6_col3" class="data row6 col3" >7</td>
#       <td id="T_164bf_row6_col4" class="data row6 col4" >Метод Гринберри</td>
#     </tr>
#     <tr>
#       <th id="T_164bf_level0_row7" class="row_heading level0 row7" >17</th>
#       <td id="T_164bf_row7_col0" class="data row7 col0" >1097558</td>
#       <td id="T_164bf_row7_col1" class="data row7 col1" >8486</td>
#       <td id="T_164bf_row7_col2" class="data row7 col2" >3131.678570</td>
#       <td id="T_164bf_row7_col3" class="data row7 col3" >8</td>
#       <td id="T_164bf_row7_col4" class="data row7 col4" >Мой создатель</td>
#     </tr>
#     <tr>
#       <th id="T_164bf_level0_row8" class="row_heading level0 row8" >19</th>
#       <td id="T_164bf_row8_col0" class="data row8 col0" >1097558</td>
#       <td id="T_164bf_row8_col1" class="data row8 col1" >6645</td>
#       <td id="T_164bf_row8_col2" class="data row8 col2" >2593.988666</td>
#       <td id="T_164bf_row8_col3" class="data row8 col3" >9</td>
#       <td id="T_164bf_row8_col4" class="data row8 col4" >Беги, Лола, беги</td>
#     </tr>
#     <tr>
#       <th id="T_164bf_level0_row9" class="row_heading level0 row9" >20</th>
#       <td id="T_164bf_row9_col0" class="data row9 col0" >1097558</td>
#       <td id="T_164bf_row9_col1" clas

# %%
# Посмотрим на рекомендации для аватаров от модели с лучшим показателем Serendipity
trial_idx = report.sort_values('Serendipity', ascending=False).index[0]
model = objective.get_model(study.trials[trial_idx])
model.fit(dataset)

avatar_recs = model.recommend(
    users=avatar_ids,
    dataset=dataset,
    k=10,
    filter_viewed=True,
).merge(
    items[[Columns.Item, 'title']],
    on=Columns.Item,
).sort_values(
    [Columns.User, Columns.Rank],
)

avatar_recs.style.apply(highlight_avatars, axis=1)
# Out:
# <style type="text/css">
# #T_c1d00_row0_col0, #T_c1d00_row0_col1, #T_c1d00_row0_col2, #T_c1d00_row0_col3, #T_c1d00_row0_col4, #T_c1d00_row1_col0, #T_c1d00_row1_col1, #T_c1d00_row1_col2, #T_c1d00_row1_col3, #T_c1d00_row1_col4, #T_c1d00_row2_col0, #T_c1d00_row2_col1, #T_c1d00_row2_col2, #T_c1d00_row2_col3, #T_c1d00_row2_col4, #T_c1d00_row3_col0, #T_c1d00_row3_col1, #T_c1d00_row3_col2, #T_c1d00_row3_col3, #T_c1d00_row3_col4, #T_c1d00_row4_col0, #T_c1d00_row4_col1, #T_c1d00_row4_col2, #T_c1d00_row4_col3, #T_c1d00_row4_col4, #T_c1d00_row5_col0, #T_c1d00_row5_col1, #T_c1d00_row5_col2, #T_c1d00_row5_col3, #T_c1d00_row5_col4, #T_c1d00_row6_col0, #T_c1d00_row6_col1, #T_c1d00_row6_col2, #T_c1d00_row6_col3, #T_c1d00_row6_col4, #T_c1d00_row7_col0, #T_c1d00_row7_col1, #T_c1d00_row7_col2, #T_c1d00_row7_col3, #T_c1d00_row7_col4, #T_c1d00_row8_col0, #T_c1d00_row8_col1, #T_c1d00_row8_col2, #T_c1d00_row8_col3, #T_c1d00_row8_col4, #T_c1d00_row9_col0, #T_c1d00_row9_col1, #T_c1d00_row9_col2, #T_c1d00_row9_col3, #T_c1d00_row9_col4 {
#   background-color: lavender;
# }
# #T_c1d00_row10_col0, #T_c1d00_row10_col1, #T_c1d00_row10_col2, #T_c1d00_row10_col3, #T_c1d00_row10_col4, #T_c1d00_row11_col0, #T_c1d00_row11_col1, #T_c1d00_row11_col2, #T_c1d00_row11_col3, #T_c1d00_row11_col4, #T_c1d00_row12_col0, #T_c1d00_row12_col1, #T_c1d00_row12_col2, #T_c1d00_row12_col3, #T_c1d00_row12_col4, #T_c1d00_row13_col0, #T_c1d00_row13_col1, #T_c1d00_row13_col2, #T_c1d00_row13_col3, #T_c1d00_row13_col4, #T_c1d00_row14_col0, #T_c1d00_row14_col1, #T_c1d00_row14_col2, #T_c1d00_row14_col3, #T_c1d00_row14_col4, #T_c1d00_row15_col0, #T_c1d00_row15_col1, #T_c1d00_row15_col2, #T_c1d00_row15_col3, #T_c1d00_row15_col4, #T_c1d00_row16_col0, #T_c1d00_row16_col1, #T_c1d00_row16_col2, #T_c1d00_row16_col3, #T_c1d00_row16_col4, #T_c1d00_row17_col0, #T_c1d00_row17_col1, #T_c1d00_row17_col2, #T_c1d00_row17_col3, #T_c1d00_row17_col4, #T_c1d00_row18_col0, #T_c1d00_row18_col1, #T_c1d00_row18_col2, #T_c1d00_row18_col3, #T_c1d00_row18_col4, #T_c1d00_row19_col0, #T_c1d00_row19_col1, #T_c1d00_row19_col2, #T_c1d00_row19_col3, #T_c1d00_row19_col4 {
#   background-color: wheat;
# }
# #T_c1d00_row20_col0, #T_c1d00_row20_col1, #T_c1d00_row20_col2, #T_c1d00_row20_col3, #T_c1d00_row20_col4, #T_c1d00_row21_col0, #T_c1d00_row21_col1, #T_c1d00_row21_col2, #T_c1d00_row21_col3, #T_c1d00_row21_col4, #T_c1d00_row22_col0, #T_c1d00_row22_col1, #T_c1d00_row22_col2, #T_c1d00_row22_col3, #T_c1d00_row22_col4, #T_c1d00_row23_col0, #T_c1d00_row23_col1, #T_c1d00_row23_col2, #T_c1d00_row23_col3, #T_c1d00_row23_col4, #T_c1d00_row24_col0, #T_c1d00_row24_col1, #T_c1d00_row24_col2, #T_c1d00_row24_col3, #T_c1d00_row24_col4, #T_c1d00_row25_col0, #T_c1d00_row25_col1, #T_c1d00_row25_col2, #T_c1d00_row25_col3, #T_c1d00_row25_col4, #T_c1d00_row26_col0, #T_c1d00_row26_col1, #T_c1d00_row26_col2, #T_c1d00_row26_col3, #T_c1d00_row26_col4, #T_c1d00_row27_col0, #T_c1d00_row27_col1, #T_c1d00_row27_col2, #T_c1d00_row27_col3, #T_c1d00_row27_col4, #T_c1d00_row28_col0, #T_c1d00_row28_col1, #T_c1d00_row28_col2, #T_c1d00_row28_col3, #T_c1d00_row28_col4, #T_c1d00_row29_col0, #T_c1d00_row29_col1, #T_c1d00_row29_col2, #T_c1d00_row29_col3, #T_c1d00_row29_col4 {
#   background-color: mistyrose;
# }
# </style>
# <table id="T_c1d00">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1d00_level0_col0" class="col_heading level0 col0" >user_id</th>
#       <th id="T_c1d00_level0_col1" class="col_heading level0 col1" >item_id</th>
#       <th id="T_c1d00_level0_col2" class="col_heading level0 col2" >score</th>
#       <th id="T_c1d00_level0_col3" class="col_heading level0 col3" >rank</th>
#       <th id="T_c1d00_level0_col4" class="col_heading level0 col4" >title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1d00_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c1d00_row0_col0" class="data row0 col0" >1097558</td>
#       <td id="T_c1d00_row0_col1" class="data row0 col1" >10440</td>
#       <td id="T_c1d00_row0_col2" class="data row0 col2" >187877.000000</td>
#       <td id="T_c1d00_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_c1d00_row0_col4" class="data row0 col4" >Хрустальный</td>
#     </tr>
#     <tr>
#       <th id="T_c1d00_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_c1d00_row1_col0" class="data row1 col0" >1097558</td>
#       <td id="T_c1d00_row1_col1" class="data row1 col1" >15297</td>
#       <td id="T_c1d00_row1_col2" class="data row1 col2" >178630.000000</td>
#       <td id="T_c1d00_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_c1d00_row1_col4" class="data row1 col4" >Клиника счастья</td>
#     </tr>
#     <tr>
#       <th id="T_c1d00_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_c1d00_row2_col0" class="data row2 col0" >1097558</td>
#       <td id="T_c1d00_row2_col1" class="data row2 col1" >9728</td>
#       <td id="T_c1d00_row2_col2" class="data row2 col2" >117779.000000</td>
#       <td id="T_c1d00_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_c1d00_row2_col4" class="data row2 col4" >Гнев человеческий</td>
#     </tr>
#     <tr>
#       <th id="T_c1d00_level0_row3" class="row_heading level0 row3" >9</th>
#       <td id="T_c1d00_row3_col0" class="data row3 col0" >1097558</td>
#       <td id="T_c1d00_row3_col1" class="data row3 col1" >13865</td>
#       <td id="T_c1d00_row3_col2" class="data row3 col2" >113875.000000</td>
#       <td id="T_c1d00_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_c1d00_row3_col4" class="data row3 col4" >Девятаев</td>
#     </tr>
#     <tr>
#       <th id="T_c1d00_level0_row4" class="row_heading level0 row4" >12</th>
#       <td id="T_c1d00_row4_col0" class="data row4 col0" >1097558</td>
#       <td id="T_c1d00_row4_col1" class="data row4 col1" >4151</td>
#       <td id="T_c1d00_row4_col2" class="data row4 col2" >85117.000000</td>
#       <td id="T_c1d00_row4_col3" class="data row4 col3" >5</td>
#       <td id="T_c1d00_row4_col4" class="data row4 col4" >Секреты семейной жизни</td>
#     </tr>
#     <tr>
#       <th id="T_c1d00_level0_row5" class="row_heading level0 row5" >15</th>
#       <td id="T_c1d00_row5_col0" class="data row5 col0" >1097558</td>
#       <td id="T_c1d00_row5_col1" class="data row5 col1" >3734</td>
#       <td id="T_c1d00_row5_col2" class="data row5 col2" >68835.000000</td>
#       <td id="T_c1d00_row5_col3" class="data row5 col3" >6</td>
#       <td id="T_c1d00_row5_col4" class="data row5 col4" >Прабабушка легкого поведения</td>
#     </tr>
#     <tr>
#       <th id="T_c1d00_level0_row6" class="row_heading level0 row6" >18</th>
#       <td id="T_c1d00_row6_col0" class="data row6 col0" >1097558</td>
#       <td id="T_c1d00_row6_col1" class="data row6 col1" >2657</td>
#       <td id="T_c1d00_row6_col2" class="data row6 col2" >66017.000000</td>
#       <td id="T_c1d00_row6_col3" class="data row6 col3" >7</td>
#       <td id="T_c1d00_row6_col4" class="data row6 col4" >Подслушано</td>
#     </tr>
#     <tr>
#       <th id="T_c1d00_level0_row7" class="row_heading level0 row7" >21</th>
#       <td id="T_c1d00_row7_col0" class="data row7 col0" >1097558</td>
#       <td id="T_c1d00_row7_col1" class="data row7 col1" >4880</td>
#       <td id="T_c1d00_row7_col2" class="data row7 col2" >52909.000000</td>
#       <td id="T_c1d00_row7_col3" class="data row7 col3" >8</td>
#       <td id="T_c1d00_row7_col4" class="data row7 col4" >Афера</td>
#     </tr>
#     <tr>
#       <th id="T_c1d00_level0_row8" class="row_heading level0 row8" >24</th>
#       <td id="T_c1d00_row8_col0" class="data row8 col0" >1097558</td>
#       <td id="T_c1d00_row8_col1" class="data row8 col1" >142</td>
#       <td id="T_c1d00_row8_col2" class="data row8 col2" >42466.000000</td>
#       <td id="T_c1d00_row8_col3" class="data row8 col3" >9</td>
#       <td id="T_c1d00_row8_col4" class="data row8 col4" >Маша</td>
#     </tr>
#     <tr>
#       <th id="T_c1d00_level0_row9" class="row_heading level0 row9" >27</th>
#       <td id="T_c1d00_row9_col0" class="data row9 col0" >1097558</td>
#       <td id="T_c1d00_row9_col1" class="data row9 col1" >6809</td>
#       <

# %%
# Создадим полный датасет
interactions, users, items = read_data()

users = users.loc[users[Columns.User].isin(interactions[Columns.User])].copy()
items = items.loc[items[Columns.Item].isin(interactions[Columns.Item])].copy()

user_features = get_user_features(users, ['sex', 'age', 'income'])
item_features = get_item_features(items, ['content_type'] + items.columns[-10:])

dataset = Dataset.construct(
    interactions_df=interactions,
    user_features_df=user_features,
    cat_user_features=['sex', 'age', 'income'],
    item_features_df=item_features,
    cat_item_features=['content_type'] + items.columns[-10:],
)

# %%
# Обучим модель на полном датасете и сохраним ее
best_model.fit(dataset)

save_model(
    best_model,
    'best_model',
    study.best_trial.params['model'],
    dataset,
    interactions,
)
